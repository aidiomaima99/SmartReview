# %% [markdown]
# # SmartReview — Expérimentation (Step 5)
# **Master BD & IA** — AIDI Omaima | ELMOUSSAOUI Fatima
# Benchmark NB / LR / SVM / RF sur IMDb 50K avec TF-IDF

# %%
# Lancer l'expérience complète depuis la racine du projet :
# !python3 ../src/train_evaluate.py

import pandas as pd
from IPython.display import display, Image
import json

metrics = pd.read_csv('../results/metrics_all.csv')
display(metrics)

with open('../results/hypotheses_validation.json') as f:
    hyp = json.load(f)
for k, v in hyp.items():
    print(k, '→', 'CONFIRMÉE' if v['confirmed'] else 'NUANCÉE', '—', v['comment'])

Image('../results/figures/metrics_comparison.png')
